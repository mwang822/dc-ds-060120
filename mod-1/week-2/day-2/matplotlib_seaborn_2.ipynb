# %% [markdown]
# ![matplotlib](https://matplotlib.org/_static/logo2.png)
#
# # Data Visualization with Matplotlib
#
#
# ## Why is visualization important?
#
#
# There are a lot of visualizations out there these days.
#
# Ultimately they are about quickly revealing relationships and anomolies.
#
# While we will review what makes a **GOOD** visualization later, we will cover a few basic types today.
#
# Let's look at some [examples from python graphs](https://python-graph-gallery.com/)

# %%
import matplotlib.pyplot as plt
import numpy as np
import calendar
# %matplotlib inline

# %% [markdown]
# ### Matplotlib - 101
#
# - First release is in 2003
#
# - Compatible with different operating systems and graphic backends: [Backends?](https://askubuntu.com/questions/417160/what-is-a-backend-in-computer-graphics)
#
# - Everything to everyone approach
#
# - Didn't age well :)

# %%
# %matplotlib

## you might see TkAgg, nbAgg for example
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# ### Setting Styles

# %%
plt.style.available[:5]
# Out:
# ['seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-whitegrid']

# %%
## for no reason :)
plt.style.use('fivethirtyeight')

# %%
plt.scatter(x = [1,4,6,8], y = [1,8,2,1])
plt.show()

# %% [markdown]
# <img src="https://python-graph-gallery.com/wp-content/uploads/Logo_PGG_full-3.jpg" width=600>
#
# The [Python Graph Gallery](https://python-graph-gallery.com/matplotlib/) has some great resources to guide you through the code needed to create each type of matplotlib plot.
#
# ## Plot Anatomy
# Let's spend some time on the terminology of a plot. There are a lot of options to set in matplotlib plots, so let's identify some common terminology.
#
# The sequence of events with matplotlib are:
#
# | Step | Code Example |
# | :---- | :------------ |
# | 1. Create figure | `fig = plt.figure(figsize=(2, 4))` |
# | 2. Create axis object | `ax = plt.subplot()` |
# | 3. Make adjustments | `plt.title`, `ax.set_xticks`, etc |
# | 4. Show final plot | `plt.show()` . |
#
#
# The [Pyplot tutorial](https://matplotlib.org/tutorials/introductory/pyplot.html) shows a list of options you can set within a plot.
#
# <img src="https://matplotlib.org/_images/sphx_glr_anatomy_001.png" width=550>
#
#
# Let's look [how they created this plot.](https://matplotlib.org/gallery/showcase/anatomy.html)
#
# [What is ax and figure?](https://stackoverflow.com/questions/34162443/why-do-many-examples-use-fig-ax-plt-subplots-in-matplotlib-pyplot-python)

# %%
x = np.linspace(0, 10, 1000)

# %%
fig = plt.figure()
ax = plt.axes()

# %%
# %matplotlib inline
fig = plt.figure()
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x), color = 'c')
plt.plot(x, np.cos(x), linestyle= 'dashed')

# %%
## limits of the axes

plt.plot(x, np.sin(x))
plt.plot(x, 100*np.cos(x), linestyle= '-.')

# %%
## limits of the axes

plt.plot(x, np.sin(x))
plt.plot(x, 4*np.cos(x), linestyle= '-.')
plt.xlim(-5*np.pi, 5*np.pi)
plt.ylim(-4,4)
# Out:
# (-4, 4)

# %%
## limits of the axes

plt.plot(x, np.sin(x))
plt.plot(x, 4*np.cos(x), linestyle= '-.')
## [xmin, xmax, ymin, ymax]
plt.axis([-0,10, -5, 5])
# Out:
# [0, 10, -5, 5]

# %%
plt.plot(x, np.sin(x))
plt.plot(x, 4*np.cos(x), linestyle= '-.')
## we can use 'equal', 'tight', 'scaled' etc.
plt.axis('square')
# Out:
# (-0.5, 10.5, -4.3999949515635155, 6.6000050484364845)

# %% [markdown]
# ### Labeling Plots

# %%
plt.plot(x, (np.sin(x**2)), label = "Murat's fav plot")
plt.title("$\sin(x^{2})$ Curve")
plt.xlabel("x")
plt.ylabel("$\sin(x^{2})$");
plt.legend(loc = 5)

# %% [markdown]
# Transition from `plt` to `ax`
#
# <img src='images/styles.png' width = 300 />

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
       xlabel='x', ylabel='sin(x)',
       title='A Simple Plot');

# %% [markdown]
# [For the scatter plots](https://jakevdp.github.io/PythonDataScienceHandbook/04.02-simple-scatter-plots.html)

# %% [markdown]
# ## Barplots
# Barplots are used for displaying __one dimensional__, __categorical__ data. You call plt.bar with two arguments:
# - the x — a list of x-positions for each bar
# - the y-values — a list of heights for each bar

# %%
import pandas as pd

# %%
# an example of a bar plot
ax = plt.subplot()
our_dogs = pd.Series(["dengue", "dolce", "murraysl", "dog_a", "dog_b", "dog_c"])
dogs_age = pd.Series([5, 8, 5, 4, 6, 7])

plt.bar(x = our_dogs, height = dogs_age)

# set ticks values, as a method of the axes
ax.set_xticks(range(0, len(our_dogs)))
ax.set_xticklabels(our_dogs)

plt.title('age of random dogs')
plt.xlabel('dogs')
plt.ylabel('age')
plt.xticks(rotation = 45)
plt.show()

# %%
# utilizing the subplot function and creating subplots
our_cats = ["cat_1", "cat_2", "cat_3", "cat_4", "cat_5", "cat_6"]
cats_age = [14, 16, 17, 20, 18, 24]
fig = plt.figure(figsize=(15, 10))
plt.subplot(1,2,1)
plt.bar(range(len(our_dogs)), dogs_age, color='pink')
plt.title('dog age')
plt.xlabel('dog number')
plt.subplot(1,2,2)
plt.bar(range(len(our_cats)), cats_age, color='green')
plt.xlabel('cat number')
plt.ylabel('Age')
plt.title('cat age')
# Out:
# Text(0.5, 1.0, 'cat age')

# %%
# we can create overlaid or side-by-side bargraph. You need
# to shift the x value by width to accommodate for two graphs.

fig = plt.figure(figsize= (15, 8))
n = 1  # This is our first dataset (out of 2)
t = 2  # Number of datasets
d = 6  # Number of sets of bars
w = 0.8  # Width of each bar

# essentially, this list comprehension gives us the position
dog_values = [t*element + w*n for element in range(d)]

# of the position of dogs
plt.bar(dog_values, dogs_age, color='green')


n = 2  # This is our second dataset (out of 2)
t = 2  # Number of datasets
d = 6  # Number of sets of bars
w = 0.8  # Width of each bar

cat_values = [t*element + w*n for element in range(d)]

plt.bar(cat_values, cats_age, color='purple')
plt.legend(["dogs", "cats"])

# %%
print(dog_values)
print(cat_values)
# Out:
# [0.8, 2.8, 4.8, 6.8, 8.8, 10.8]
# [1.6, 3.6, 5.6, 7.6, 9.6, 11.6]

# %%
# stacked barplots
ax = plt.subplot()
music_festivals = ["Coachella", "Govball", "EDC", "Ultra"]
ticket_sales_in_millon = [114, 62, 120, 116]
people_attended_in_thousands = [126, 114, 130, 110]

plt.bar(range(len(music_festivals)),
        ticket_sales_in_millon)
plt.bar(range(len(music_festivals)),
        people_attended_in_thousands,
        bottom=ticket_sales_in_millon)

plt.legend(["tix sales", "number of people"])
ax.set_xticks(range(0, len(music_festivals)))
ax.set_xticklabels(music_festivals)
plt.show()

# %% [markdown]
# ## Bar plot - animal shelter dataset
#
# Let's make a bar plot comparing dogs and cats by month when they are admitted to the shelter.

# %%
shelter_df = pd.read_csv('https://data.austintexas.gov/api/views/9t4d-g238/rows.csv?accessType=DOWNLOAD')

# %%
shelter_df.columns = [x.lower().replace(' ','_') for x in shelter_df.columns]

# %%
shelter_df.head(50)
# Out:
#    animal_id          name                datetime               monthyear  \
# 0    A794011         Chunk  05/08/2019 06:20:00 PM  05/08/2019 06:20:00 PM
# 1    A776359         Gizmo  07/18/2018 04:02:00 PM  07/18/2018 04:02:00 PM
# 2    A720371         Moose  02/13/2016 05:59:00 PM  02/13/2016 05:59:00 PM
# 3    A674754           NaN  03/18/2014 11:47:00 AM  03/18/2014 11:47:00 AM
# 4    A689724    *Donatello  10/18/2014 06:52:00 PM  10/18/2014 06:52:00 PM
# 5    A680969         *Zeus  08/05/2014 04:59:00 PM  08/05/2014 04:59:00 PM
# 6    A684617           NaN  07/27/2014 09:00:00 AM  07/27/2014 09:00:00 AM
# 7    A742354       Artemis  01/22/2017 11:56:00 AM  01/22/2017 11:56:00 AM
# 8    A681036           NaN  06/11/2014 05:11:00 PM  06/11/2014 05:11:00 PM
# 9    A803149        *Birch  08/31/2019 04:26:00 PM  08/31/2019 04:26:00 PM
# 10   A698049         Luigi  03/16/2015 02:50:00 PM  03/16/2015 02:50:00 PM
# 11   A773792           NaN  06/05/2018 03:30:00 PM  06/05/2018 03:30:00 PM
# 12   A725795           NaN  05/03/2016 12:39:00 PM  05/03/2016 12:39:00 PM
# 13   A730621         *Liza  09/10/2016 06:59:00 PM  09/10/2016 06:59:00 PM
# 14   A765349      Einstein  06/08/2018 01:04:00 PM  06/08/2018 01:04:00 PM
# 15   A760697          Star  10/26/2017 03:22:00 PM  10/26/2017 03:22:00 PM
# 16   A767231        Millie  02/25/2018 05:19:00 PM  02/25/2018 05:19:00 PM
# 17   A758536           NaN  09/23/2017 11:09:00 AM  09/23/2017 11:09:00 AM
# 18   A754682      Big Girl  07/23/2017 11:58:00 AM  07/23/2017 11:58:00 AM
# 19   A801106           NaN  08/16/2019 02:05:00 PM  08/16/2019 02:05:00 PM
# 20   A766700           NaN  02/15/2018 08:59:00 AM  02/15/2018 08:59:00 AM
# 21   A740079         Terry  12/26/2016 01:45:00 PM  12/26/2016 01:45:00 PM
# 22   A757919         *Tofu  10/05/2017 03:36:00 PM  10/05/2017 03:36:00 PM
# 23   A789298  *Mr Wrinkles  04/23/2019 11:59:00 AM  04/23/2019 11:59:00 AM
# 24   A773866        *Nitro  08/23/2018 06:05:00 PM  08/23/2018 06:05:00 PM
# 25   A765701           NaN  01/25/2018 09:39:00 AM  01/25/2018 09:39:00 AM
# 26   A699884           NaN  04/03/2015 04:16:00 PM  04/03/2015 04:16:00 PM
# 27   A725530          King  06/09/2016 02:50:00 PM  06/09/2016 02:50:00 PM
# 28   A722378        Canine  03/31/2016 07:08:00 PM  03/31/2016 07:08:00 PM
# 29   A707743           NaN  07/18/2015 09:00:00 AM  07/18/2015 09:00:00 AM
# 30   A681449        Buster  07/02/2014 07:01:00 PM  07/02/2014 07:01:00 PM
# 31   A738919          Milo  11/27/2016 05:35:00 PM  11/27/2016 05:35:00 PM
# 32   A730464           NaN  07/05/2016 12:47:00 PM  07/05/2016 12:47:00 PM
# 33   A805930       *Rachel  11/08/2019 06:37:00 PM  11/08/2019 06:37:00 PM
# 34   A672423     Valentine  02/14/2014 11:44:00 AM  02/14/2014 11:44:00 AM
# 35   A665383        Indica  10/30/2013 04:23:00 PM  10/30/2013 04:23:00 PM
# 36   A806497          *Moo  12/17/2019 05:59:00 PM  12/17/2019 05:59:00 PM
# 37   A754899         Puppy  07/29/2017 05:57:00 PM  07/29/2017 05:57:00 PM
# 38   A746498          Zeus  05/03/2017 07:25:00 PM  05/03/2017 07:25:00 PM
# 39   A810161        Lizzie  12/19/2019 03:54:00 PM  12/19/2019 03:54:00 PM
# 40   A791163           NaN  03/24/2019 08:22:00 AM  03/24/2019 08:22:00 AM
# 41   A777234         Tyson  01/02/2019 12:00:00 AM  01/02/2019 12:00:00 AM
# 42   A684009       Big Boy  07/19/2014 06:32:00 PM  07/19/2014 06:32:00 PM
# 43   A757815           NaN  09/07/2017 11:00:00 AM  09/07/2017 11:00:00 AM
# 44   A792258        Vesper  04/10/2019 08:53:00 PM  04/10/2019 08:53:00 PM
# 45   A802723     *Linguine  09/20/2019 06:27:00 PM  09/20/2019 06:27:00 PM
# 46   A705205         *Dell  06/20/2015 04:25:00 PM  06/20/2015 04:25:00 PM
# 47   A689228         Louie  12/05/2014 03:55:00 PM  12/05/2014 03:55:00 PM
# 48   A688837     *Sterling  10/13/2014 06:14:00 PM  10/13/2014 06:14:00 PM
# 49   A634392        Junior  03/24/2018 03:56:00 PM  03/24/2018 03:56:00 PM
#
#    date_of_birth     outcome_type outcome_subtype animal_type  \
# 0     05/02/2017        Rto-Adopt             NaN         Cat
# 1     07/12/2017         Adoption             NaN         Dog
# 2     10/08/2015         Adoption             NaN         Dog
# 3     03/12/2014         Transfer         Partner         Cat
# 4     08/01/2014         Adoption             NaN         Cat
# 5     06/03/2014         Adoption             NaN         Cat
# 6     07/26/2012         Transfer            SCRP         Cat
# 7     01/20/2010  Return to Owner             NaN         Cat
# 8     06/09/2014         Transfer         Partner         Cat
# 9     08/08/2019         Transfer         Partner         Cat
# 10    06/05/2014         Transfer         Partner         Cat
# 11    05/05/2018       Euthanasia       Suffering         Cat
# 12    04/15/2016       Euthanasia        Underage       Other
# 13    05/18/2016         Adoption             NaN         Cat
# 14    01/18/2009         Adoption          Foster         Dog
# 15    10/23/2007         Transfer         Partner         Dog
# 16    02/25/2017  Return to Owner             NaN         Dog
# 17    03/18/2017         Transfer             Snr         Cat
# 18    07/22/2009  Return to Owner             NaN         Dog
# 19    05/06/2019         Adoption             NaN         Cat
# 20    02/15/2017       Euthanasia     Rabies Risk       Other
# 21    12/10/2013  Return to Owner             NaN         Dog
# 22    09/08/2015         Adoption             NaN         Dog
# 23    02/15/2019         Adoption          Foster         Dog
# 24    06/06/2016         Adoption             NaN         Dog
# 25    01/25/2017       Euthanasia     Rabies Risk       Other
# 26    04/03/2013       Euthanasia       Suffering         Cat
# 27    10/30/2015         Adoption             NaN         Dog
# 28    03/15/2010  Return to Owner             NaN         Dog
# 29    04/17/2015         Transfer            SCRP         Cat
# 30    06/16/2010  Return to Owner             NaN         Dog
# 31    09/23/2016         Adoption             NaN         Dog
# 32    07/05/2015       Euthanasia     Rabies Risk       Other
# 33    09/11/2019         Adoption          Foster         Dog
# 34    02/10/2002         Transfer         Partner         Dog
# 35    06/19/2013         Adoption             NaN         Dog
# 36    06/02/2019         Adoption             NaN       Other
# 37    07/26/2012         Adoption             NaN         Dog
# 38    04/04/2016         Adoption             NaN         Dog
# 39    10/15/2019         Adoption             NaN         Dog
# 40    02/22/2019             Died       In Kennel         Cat
# 41    11/25/2017         Transfer         Partner         Dog
# 42    07/18/2012  Return to Owner             NaN         Dog
# 43    09/07/2015       Euthanasia     Rabies Risk       Other
# 44    09/08/2016         Adoption             NaN         Cat
# 45    07/09/2019         Adoption          Foster         Dog
# 46    03/30/2015         Adoption         Offsite         Cat
# 47    06/01/2014         Adoption             NaN         Dog
# 48    09/24/2013         Adoption             NaN         Dog
# 49    08/11/2009  Return to Owner             NaN         Dog
#
#    sex_upon_outcome age_upon_outcome  \
# 0     Neutered Male          2 years
# 1     Neutered Male           1 year
# 2     Neutered Male         4 months
# 3       Intact Male           6 days
# 4     Neutered Male         2 months
# 5     Neutered Male         2 months
# 6     Intact Female          2 years
# 7     Neutered Male          7 years
# 8       Intact Male           2 days
# 9       Intact Male          3 weeks
# 10    Spayed Female         9 months
# 11      Intact Male          4 weeks
# 12          Unknown          2 weeks
# 13    Spayed Female         3 months
# 14    Neutered Male          9 years
# 15      Intact Male         10 years
# 16    Spayed Female           1 year
# 17    Intact Female         6 months
# 18    Spayed Female          8 years
# 19    Neutered Male         3 months
# 20          Unknown           1 year
# 21    Neutered Male          3 years
# 22    Spayed Female          2 years
# 23    Neutered Male         2 months
# 24    Neutered Male          2 years
# 25          Unknown           1 year
# 26          Unknown          2 years
# 27    Neutered Male         7 months
# 28    Neutered Male          6 years
# 29      Intact Male         3 months
# 30    Neutered Male          4 years
# 31    Neutered Male         2 months
# 32          Unknown           1 year
# 33    Spayed Female          1 month
# 34    Spayed Female         12 years
# 35    Spayed Female         4 months
# 36    Spayed Female         6 months
# 37    Spayed Female          5 years
# 38    Neutered Male           1 year
# 39    Spayed Female         2 months
# 40          Unknown          4 weeks
# 41    Neutered Male           1 year
# 42    Neutered Male          2 years
# 43          Unknown          2 years
# 44    Spayed Female          2 years
# 45    Spayed Female         2 months
# 46    Neutered Male         2 months
# 47    Neutered Male         6 months
# 48    Neutered Male           1 year
# 49    Neutered Male          8 years
#
#                                        breed                color month
# 0                     Domestic Shorthair Mix    Brown Tabby/White    05
# 1                    Chihuahua Shorthair Mix          White/Brown    07
# 2         Anatol Shepherd/Labrador Retriever                 Buff    02
# 3                     Domestic Shorthair Mix         Orange Tabby    03
# 4                     Domestic Shorthair Mix                Black    10
# 5                     Domestic Shorthair Mix   White/Orange Tabby    08
# 6                     Domestic Shorthair Mix                Black    07
# 7                     Domestic Shorthair Mix           Blue/White    01
# 8                     Domestic Shorthair Mix          Brown Tabby    06
# 9                         Domestic Shorthair          Brown Tabby    08
# 10                  Domestic Medium Hair Mix          Black/White    03
# 11                    Domestic Shorthair Mix         Orange Tabby    06
# 12                                   Opossum                 Gray    05
# 13                    Domestic Shorthair Mix               Calico    09
# 14                   Chihuahua Shorthair Mix             Tricolor    06
# 15                     Yorkshire Terrier Mix          Brown/Black    10
# 16  Jack Russell Terrier/Chihuahua Shorthair            White/Tan    02
# 17                    Domestic Shorthair Mix          Brown Tabby    09
# 18                        Great Pyrenees Mix                White    07
# 19                        Domestic Shorthair         Orange Tabby    08
# 20                                   Bat Mix                Brown    02
# 21                 Australian Cattle Dog Mix          Black/White    12
# 22                                Beagle Mix          Brown/White    10
# 23                    Labrador Retriever Mix          Brown/White    04
# 24          Labrador Retriever/Staffordshire          Black/White    08
# 25                                   Bat Mix                Brown    01
# 26                    Domestic Shorthair Mix                 Gray    04
# 27                              Pit Bull Mix  Brown Brindle/White    06
# 28                       German Shepherd Mix          Brown/Black    03
# 29                    Domestic Shorthair Mix          Black/White    07
# 30                        Dogo Argentino Mix          White/Brown    07
# 31                       Black Mouth Cur Mix          Brown/Black    11
# 32                                       Bat          Black/Brown    07
# 33                         Border Collie Mix      Chocolate/White    11
# 34                          Collie Rough Mix                  Red    02
# 35                       German Shepherd Mix            Black/Tan    10
# 36                                    Polish          White/White    12
# 37                       German Shepherd Mix          Brown/Black    07
# 38          Rat Terrier/Cardigan Welsh Corgi          Black/White    05
# 39                     Australian Cattle Dog      Blue Tick/Black    12
# 40                    Domestic Shorthair Mix          Black/White    03
# 41                              Pit Bull Mix           Blue/White    01
# 42        American Staffordshire Terrier Mix  Brown Brindle/White    07
# 43                                   Raccoon           Gray/Black    09
# 44                    Domestic Shorthair Mix               Tortie    04
# 45                      Miniature Poodle Mix                  Tan    09
# 46                    Domestic Shorthair Mix     White/Blue Tabby    06
# 47             Dachshund/Chihuahua Shorthair            Sable/Tan    12
# 48                   Chihuahua Shorthair Mix            Tan/White    10
# 49       Standard Schnauzer/Miniature Poodle                White    03

# %%
## Let's drop all the missing values first

## Note that here we choose that method for the sake of simplicity.
## Normally we should be careful about how to deal with missing values.

# %%
## Let's take a look at the shape and first 3 rows of the dataset
shelter_df['month'] = shelter_df.monthyear.apply(lambda x: str(x).split('/',1)[0])

# %%
## Which animal type has the most number in this data?

# %%
numMonth = shelter_df.month.value_counts()

# %%
## what is the outcome types and especially for animal types what is the distribution of outcomes?
# Out:
# --------------------------------------------------
# AttributeError   Traceback (most recent call last)
# <ipython-input-54-0fde847f97ac> in <module>
#       1 ## what is the outcome types and especially for animal types what is the distribution of outcomes?
# ----> 2 datetime.month
#
# AttributeError: module 'datetime' has no attribute 'month'

# %%
plt.bar(x=numMonth.index , height=numMonth)
# Out:
# <BarContainer object of 12 artists>

# %%
## what is the average number of days for outcomes for different animal_types

# %%
## Which month is the busiest moth in terms of action?

# %%
## How is the distribution of outcomes to months?

# %% [markdown]
# ## Histogram
# Histograms are like barplots in the sense that it describe __one-dimensional__ data. A histogram divides the variable into bins, counts the number of observations in each bin, and shows the bins on the x-axis and the frequency on the y-axis. It is used for visualizing __continuous__ variables. <br>
#
# From the documentation: compute and draw the histogram of x. The return value is a tuple (__n, bins, patches__) or ([n0, n1, ...], bins, [patches0, patches1,...]) if the input contains multiple data.

# %% [markdown]
# <img src= 'images/histogram-basic-example.png' width =350/>

# %%
# Set seed for reproducability
np.random.seed(2018)

# Generate 1000 values from 0 standard normal distribution
x = np.random.randn(100000)

# Plot the distogram with hist() function
plt.hist(x, bins=1000, color='purple')

plt.xlabel('Normal random distribution')
plt.ylabel('Frequency of Values')
plt.title('Histograms')
plt.show()

# %%
# overlaid histograms for two distributions
# plotting two histograms
mu1, sigma1 = 0, 0.1  # mean and standard deviation
s1 = np.random.normal(mu1, sigma1, 1000)
mu2, sigma2 = 0.2, 0.1
s2 = np.random.normal(mu2, sigma2, 1000)
plt.figure(figsize=(10, 8))
plt.hist(s1, bins=200, density=True, alpha=.5)
plt.hist(s2, bins=200, density=True, alpha=.5)
plt.show()

# %% [markdown]
# ## Scatterplot - visualizing two dimensional data
# Scatterplots are usually used for visualizing two dimensional data (observations with two variables). It allows us to examine the relationship between two variables, thus it is sometimes called a correlation plot.

# %%
# generate some data -> the sine wave
x = np.linspace(0, 10, 30)
y = np.sin(x)
plt.scatter(x, y, label="Function: sin(x)")
plt.title('Scatter Plot in Matplotlib')
plt.legend()
plt.show()

# %%
# examining correlation with height and weight
height = [63, 62, 60, 63, 64, 65, 68, 67, 64, 71, 72, 70, 73]
weight = [120, 115, 114, 119, 125, 130, 135, 140, 128, 140, 150, 165, 180]
plt.scatter(height, weight, color='r')
plt.show()

# %% [markdown]
# ## Pie Charts

# %%
# pie chart
music_genre = ['R&B', 'Rock', 'Country', 'House', 'Hip Pop', 'Techno']
num_people_like = [15, 5, 3, 7, 18, 3]

# Make your plot here
plt.figure(figsize=(10, 8))
plt.pie(num_people_like, labels=music_genre, autopct="%1d%%")

plt.axis('equal')
plt.title('Music Preference')

plt.show()

# %% [markdown]
# ![seaborn](https://d2h0cx97tjks2p.cloudfront.net/blogs/wp-content/uploads/sites/2/2018/07/seaborn.png)
#
# # The good, the bad, the seaborn
#
#
#
# [Data is ugly](https://www.reddit.com/r/dataisugly/)
#
# [Data is beatiful](https://www.reddit.com/r/dataisbeautiful/)
#
# Learning goals:
#
# - Create a list of best practices for data visualization
# - Identify the differences between matplotlib and seaborn
# - Create a visualization with seaborn, applying best practices

# %% [markdown]
# ## Best practices for data visualization
#
# Documenting best practices:
#
# After class, read these articles about the Dos and Don'ts of Visaulizations:
# - [article 1](https://www.jackhagley.com/What-s-the-difference-between-an-Infographic-and-a-Data-Visualisation)
# - [article 2](https://thoughtbot.com/blog/analyzing-minards-visualization-of-napoleons-1812-march)
# - [article 3](http://dataremixed.com/2016/04/the-design-of-everyday-visualizations/)
# - [article 4](https://visme.co/blog/data-storytelling-tips/)
# - [article 5](https://www.tableau.com/learn/articles/best-beautiful-data-visualization-examples)
# - [article 6](files/VisualizationsThatReallyWork.pdf)

# %% [markdown]
# ## Differences between seaborn & matplotlib
#
#
# ### Two code examples to accomplish the same plot:
#
# **Resources:**
# - [python graph gallery on seaborn](https://python-graph-gallery.com/seaborn/)
# - [seaborn](https://seaborn.pydata.org/)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# Load in data
tips = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# %%
# Matplotlib:

# Initialize Figure and Axes object
fig, ax = plt.subplots()

# Create violinplot
ax.violinplot(tips["total_bill"], vert=False)

# Show the plot
plt.show()

# %%
# Seaborn:

import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
tips = sns.load_dataset("tips")
# tips = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# Create violinplot

sns.violinplot(x = "total_bill", data=tips)

# Show the plot
plt.show()

# %%
g = sns.FacetGrid(tips, col="sex", hue="smoker")
g.map(plt.scatter, "total_bill", "tip", alpha=.7)
g.add_legend();

# %%
g = sns.FacetGrid(tips, col="day", height=4, aspect=.5)
g.map(sns.boxplot, "sex", "total_bill");
# Out:
# //anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:728: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ## Your turn: Create a visualization with seaborn, applying best practices
#
# [exercise from data world](https://data.world/makeovermonday/2018w37-paying-the-president)

# %%
import pandas as pd
df = pd.read_excel('https://query.data.world/s/5qxp2ldwsel3ow2pq5mkvfas2rfaup')

# %% [markdown]
# #### For extra fun:
# [visualization challenges](http://www.storytellingwithdata.com/blog/2019/3/1/swdchallenge-visualize-this-data)
#
# [seaborn cheatsheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Seaborn_Cheat_Sheet.pdf)
